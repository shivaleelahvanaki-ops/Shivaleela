# %% [markdown]
# <a href="https://colab.research.google.com/github/shivaleelahvanaki-ops/Shivaleela/blob/main/Cryptarithmetic_Constraints.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Analyzing the mean of the covid data.csv

# %%
import numpy as np
import pandas as pd

# %%
covid_data = pd.read_csv("covid-data.csv")

# %%
covid_data.head(5)
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  24/02/2020            5          5
# 1      AFG      Asia  Afghanistan  25/02/2020            5          0
# 2      AFG      Asia  Afghanistan  26/02/2020            5          0
# 3      AFG      Asia  Afghanistan  27/02/2020            5          0
# 4      AFG      Asia  Afghanistan  28/02/2020            5          0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# 1             NaN           NaN                  37.746
# 2             NaN           NaN                  37.746
# 3             NaN           NaN                  37.746
# 4             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
covid_data = covid_data[['iso_code','continent','location','date','total_cases','new_cases']]

# %%
covid_data.head(5)
# Out:
#   iso_code continent     location        date  total_cases  new_cases
# 0      AFG      Asia  Afghanistan  24/02/2020            5          5
# 1      AFG      Asia  Afghanistan  25/02/2020            5          0
# 2      AFG      Asia  Afghanistan  26/02/2020            5          0
# 3      AFG      Asia  Afghanistan  27/02/2020            5          0
# 4      AFG      Asia  Afghanistan  28/02/2020            5          0

# %%
covid_data.dtypes
# Out:
# iso_code       object
# continent      object
# location       object
# date           object
# total_cases     int64
# new_cases       int64
# dtype: object

# %%
covid_data.shape
# Out:
# (5818, 6)

# %%
data_mean = np.mean(covid_data["new_cases"])
data_mean
# Out:
# np.float64(8814.365761430045)

# %%
data_mean = covid_data["new_cases"].mean()
data_mean
# Out:
# np.float64(8814.365761430045)

# %%
data_median = np.median(covid_data["new_cases"])
data_median
# Out:
# np.float64(261.0)

# %%
data_median = covid_data["new_cases"].median()
data_median
# Out:
# 261.0

# %%
from scipy import stats

# %%
data_mode = covid_data["new_cases"].mode()
data_mode
# Out:
# 0    0
# Name: new_cases, dtype: int64

# %%
data_mode = covid_data["new_cases"].mode()
data_mode
# Out:
# 0    0
# Name: new_cases, dtype: int64

# %%
data_variance = np.var(covid_data["new_cases"])
data_variance
# Out:
# 451321915.92810047

# %%
covid_data["new_cases"].var()
# Out:
# 451399502.6422019

# %%
data_sd = np.std(covid_data["new_cases"])
data_sd
# Out:
# 21244.33844411495

# %%
covid_data["new_cases"].std()
# Out:
# 21246.16442189512

# %%
data_max = np.max(covid_data["new_cases"])
data_min = np.min(covid_data["new_cases"])

# %%
print(data_max,data_min)
# Out:
# 287149 0

# %%
data_range = data_max - data_min
data_range
# Out:
# 287149

# %%
data_max = covid_data["new_cases"].max()
data_min = covid_data["new_cases"].min()

# %%
data_range = data_max - data_min
data_range
# Out:
# 287149

# %%
data_percentile = np.percentile(covid_data["new_cases"],60)
data_percentile
# Out:
# np.float64(591.3999999999996)

# %%
data_quartile = np.quantile(covid_data["new_cases"],0.75)
data_quartile
# Out:
# np.float64(3666.0)

# %%
data_quartile = np.quantile(covid_data["new_cases"],0.75)
data_quartile
# Out:
# np.float64(3666.0)

# %%
data_IQR = stats.iqr(covid_data["new_cases"])
data_IQR
# Out:
# np.float64(3642.0)
