# %% [markdown]
# <a href="https://colab.research.google.com/github/shivaleelahvanaki-ops/Shivaleela/blob/main/Forms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer

# %%
# Download required resources
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
text = "The students are studying Artificial Intelligence in the university."

# %%
print("Original Sentence:")
print(text)
# Out:
# Original Sentence:
# The students are studying Artificial Intelligence in the university.

# %%
# Tokenization
tokens = word_tokenize(text)
print("\nTokens:")
print(tokens)
# Out:
# Tokens:
# ['The', 'students', 'are', 'studying', 'Artificial', 'Intelligence', 'in', 'the', 'university', '.']

# %%
# Stopword Removal
stop_words = set(stopwords.words('english'))
filtered_words = [word for word in tokens if word.lower() not in stop_words]

# %%
print("\nAfter Stopword Removal:")
print(filtered_words)
# Out:
# After Stopword Removal:
# ['students', 'studying', 'Artificial', 'Intelligence', 'university', '.']

# %%
# Stemming
stemmer = PorterStemmer()
stemmed = [stemmer.stem(word) for word in filtered_words]

# %%
print("\nStemmed Words:")
print(stemmed)
# Out:
# Stemmed Words:
# ['student', 'studi', 'artifici', 'intellig', 'univers', '.']

# %%
# Lemmatization
lemmatizer = WordNetLemmatizer()
lemmatized = [lemmatizer.lemmatize(word) for word in filtered_words]

# %%
print("\nLemmatized Words:")
print(lemmatized)
# Out:
# Lemmatized Words:
# ['student', 'studying', 'Artificial', 'Intelligence', 'university', '.']
